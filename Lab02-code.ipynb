# %%
Lab-01: Implement Basic Python Libraries, Matplotlib, Pandas

# %%
#Import the essential python libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
