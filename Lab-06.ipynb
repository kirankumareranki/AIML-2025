# %% [markdown]
# ## Lab -06: Implement K-Nearest neighbor Classifier using Classified Dataset
# ## Part -01

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
