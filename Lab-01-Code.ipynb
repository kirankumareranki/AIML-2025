# %% [markdown]
# Lab-01: Implement basic Pythoon Libraries using Numpy, Pandas, MatplotLib

# %%
##Part 1: Basic Numpy Arays, Lists And Perform Arthematic Operations
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
##Create arrays, list and perform arthematic operations
list1=[1,2,3]
array1= np.array(list1)
array1, list1
# Out:
# (array([1, 2, 3]), [1, 2, 3])
